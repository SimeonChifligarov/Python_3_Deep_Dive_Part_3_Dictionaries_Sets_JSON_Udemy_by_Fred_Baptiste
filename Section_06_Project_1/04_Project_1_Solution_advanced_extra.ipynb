# %% [markdown]
# # Project 1 — Advanced Solution
#
# Validate a nested dictionary against a template dictionary.
#
# ## Rules
#
# - Every template key is required.
# - Extra data keys are not permitted.
# - Nested dictionaries are validated recursively.
# - Leaf values in the template are Python type objects such as `int` or `str`.
# - Leaf values in the data must have the **exact** expected type.
# - Lists are intentionally outside the scope of this project.
# - Validation stops at the first error and reports its dotted path.
#
# The notebook provides both:
# 1. an exception-based validator (`validate_or_raise`) — the preferred API; and
# 2. a compatibility wrapper (`validate`) returning `(state, error)`.

# %% [markdown]
# ## Sample template and data

# %%
template = {
    "user_id": int,
    "name": {
        "first": str,
        "last": str,
    },
    "bio": {
        "dob": {
            "year": int,
            "month": int,
            "day": int,
        },
        "birthplace": {
            "country": str,
            "city": str,
        },
    },
}

john = {
    "user_id": 100,
    "name": {
        "first": "John",
        "last": "Cleese",
    },
    "bio": {
        "dob": {
            "year": 1939,
            "month": 11,
            "day": 27,
        },
        "birthplace": {
            "country": "United Kingdom",
            "city": "Weston-super-Mare",
        },
    },
}

eric = {
    "user_id": 101,
    "name": {
        "first": "Eric",
        "last": "Idle",
    },
    "bio": {
        "dob": {
            "year": 1943,
            "month": 3,
            "day": 29,
        },
        "birthplace": {
            "country": "United Kingdom",
        },
    },
}

michael = {
    "user_id": 102,
    "name": {
        "first": "Michael",
        "last": "Palin",
    },
    "bio": {
        "dob": {
            "year": 1943,
            "month": "May",
            "day": 5,
        },
        "birthplace": {
            "country": "United Kingdom",
            "city": "Sheffield",
        },
    },
}

# %% [markdown]
# ## Exception hierarchy
#
# Custom exceptions make failures machine-readable while still producing the exact human-readable messages requested by the project. Each exception stores the failing `path` separately from its message.

# %%
class ValidationError(Exception):
    """Base class for validation failures."""

    label = "validation error"

    def __init__(self, path):
        self.path = path
        super().__init__(self.__str__())

    def __str__(self):
        return "{}: {}".format(self.label, self.path)


class KeyMismatchError(ValidationError):
    """Raised when a required key is absent or an extra key is present."""

    label = "mismatched keys"


class BadTypeError(ValidationError):
    """Raised when a data value has the wrong type."""

    label = "bad type"

    def __init__(self, path, expected=None, actual=None):
        self.expected = expected
        self.actual = actual
        super().__init__(path)


class InvalidTemplateError(ValidationError):
    """Raised when a template leaf is neither a dict nor a type object."""

    label = "invalid template"

# %% [markdown]
# ## Recursive validator
#
# A few deliberate implementation choices:
#
# - Key equality is checked before descending, so structural errors are detected first.
# - Missing keys are reported in template insertion order; extra keys are reported in data insertion order.
# - `type(value) is expected_type` is used instead of `isinstance`. This prevents `True` from passing an `int` template because `bool` subclasses `int`.
# - The function returns `None` on success and raises on failure, which is idiomatic for an exception-based API.

# %%
def _path(parent, key):
    """Join a parent dotted path and one dictionary key."""
    key = str(key)
    return "{}.{}".format(parent, key) if parent else key


def validate_or_raise(data, template, path=""):
    """Validate data against template, raising on the first error."""
    display_path = path or "<root>"

    if not isinstance(template, dict):
        raise InvalidTemplateError(display_path)

    if not isinstance(data, dict):
        raise BadTypeError(
            display_path,
            expected=dict,
            actual=type(data),
        )

    # Check key structure before validating nested values.
    if data.keys() != template.keys():
        # Missing keys: preserve template insertion order.
        for key in template:
            if key not in data:
                raise KeyMismatchError(_path(path, key))

        # Extra keys: preserve data insertion order.
        for key in data:
            if key not in template:
                raise KeyMismatchError(_path(path, key))

    for key, expected in template.items():
        current_path = _path(path, key)
        value = data[key]

        if isinstance(expected, dict):
            validate_or_raise(value, expected, current_path)
            continue

        if not isinstance(expected, type):
            raise InvalidTemplateError(current_path)

        # Exact type comparison is intentional for this project.
        if type(value) is not expected:
            raise BadTypeError(
                current_path,
                expected=expected,
                actual=type(value),
            )

# %% [markdown]
# ## Compatibility wrapper
#
# This preserves the tuple interface requested in the original prompt while keeping the real validation logic exception-based.

# %%
def validate(data, template):
    """Return (True, "") or (False, first_error_message)."""
    try:
        validate_or_raise(data, template)
    except ValidationError as exc:
        return False, str(exc)
    return True, ""

# %% [markdown]
# ## Required project checks

# %%
assert validate(john, template) == (True, "")
assert validate(eric, template) == (
    False,
    "mismatched keys: bio.birthplace.city",
)
assert validate(michael, template) == (
    False,
    "bad type: bio.dob.month",
)

print(validate(john, template))
print(validate(eric, template))
print(validate(michael, template))
# Out:
# (True, '')
# (False, 'mismatched keys: bio.birthplace.city')
# (False, 'bad type: bio.dob.month')

# %% [markdown]
# Expected output:
#
# ```text
# (True, '')
# (False, 'mismatched keys: bio.birthplace.city')
# (False, 'bad type: bio.dob.month')
# ```

# %% [markdown]
# ## Additional edge-case tests
#
# These cover extra keys, a wrong nested container type, the `bool`/`int` corner case, an invalid template, and an empty dictionary.

# %%
# 1) Extra keys are rejected.
john_with_extra_key = {
    **john,
    "active": True,
}
assert validate(john_with_extra_key, template) == (
    False,
    "mismatched keys: active",
)

# 2) A nested object must itself be a dictionary.
wrong_nested_container = {
    **john,
    "name": "John Cleese",
}
assert validate(wrong_nested_container, template) == (
    False,
    "bad type: name",
)

# 3) Exact type semantics: bool must not silently satisfy int.
bool_as_user_id = {
    **john,
    "user_id": True,
}
assert validate(bool_as_user_id, template) == (
    False,
    "bad type: user_id",
)

# 4) Unsupported template leaves are caught explicitly.
bad_template = {
    "user_id": 0,  # should be int, not an example value
}
assert validate({"user_id": 100}, bad_template) == (
    False,
    "invalid template: user_id",
)

# 5) Empty structures are valid when both sides are empty.
assert validate({}, {}) == (True, "")

print("All edge-case tests passed.")
# Out:
# All edge-case tests passed.

# %% [markdown]
# ## Preferred exception-based usage
#
# In application code, catch specific error classes when different failure types need different handling.

# %%
try:
    validate_or_raise(michael, template)
except KeyMismatchError as exc:
    print("Structure error at:", exc.path)
except BadTypeError as exc:
    print(
        "Type error at {}: expected {}, got {}".format(
            exc.path,
            exc.expected.__name__ if exc.expected else "?",
            exc.actual.__name__ if exc.actual else "?",
        )
    )
except InvalidTemplateError as exc:
    print("Template definition error at:", exc.path)
# Out:
# Type error at bio.dob.month: expected int, got str

# %% [markdown]
# ## Complexity
#
# Let `n` be the total number of keys visited across the nested dictionaries.
#
# - **Time:** `O(n)` in the normal case.
# - **Auxiliary space:** `O(d)` for recursion, where `d` is the maximum nesting depth.
#
# For production API validation, a schema library such as `jsonschema`, Pydantic, or Marshmallow is normally preferable because real schemas often need optional fields, lists, unions, ranges, formats, coercion rules, and richer error aggregation.

# %% [markdown]
# ## Added-value extension: collect every validation error
#
# The original project intentionally stops at the first failure. That is ideal for a small validator, but API clients and batch-processing systems often benefit from receiving **all independent errors in one pass**.
#
# The extension below preserves the original `validate` and `validate_or_raise` APIs while adding:
#
# - `ValidationIssue`: a structured representation of one failure;
# - `validate_all`: returns every discoverable issue instead of stopping at the first one;
# - missing and extra keys can be reported together;
# - validation continues through keys that exist on both sides;
# - cycle protection for Python dictionaries that could otherwise recurse forever.

# %%
class ValidationIssue:
    """Structured, immutable-by-convention description of one validation problem."""

    def __init__(self, kind, path, expected=None, actual=None, detail=None):
        self.kind = kind
        self.path = path
        self.expected = expected
        self.actual = actual
        self.detail = detail

    @property
    def message(self):
        labels = {
            "missing_key": "mismatched keys",
            "extra_key": "mismatched keys",
            "bad_type": "bad type",
            "invalid_template": "invalid template",
            "cycle": "cyclic reference",
        }
        return "{}: {}".format(labels[self.kind], self.path)

    def as_dict(self):
        """Return JSON-friendly diagnostic metadata."""
        return {
            "kind": self.kind,
            "path": self.path,
            "message": self.message,
            "expected": getattr(self.expected, "__name__", None),
            "actual": getattr(self.actual, "__name__", None),
            "detail": self.detail,
        }

    def __repr__(self):
        return "ValidationIssue({!r}, {!r})".format(self.kind, self.path)

# %%
def _collect_issues(data, template, path="", data_ancestors=None, template_ancestors=None):
    """Recursively collect validation issues without raising."""
    if data_ancestors is None:
        data_ancestors = set()
    if template_ancestors is None:
        template_ancestors = set()

    display_path = path or "<root>"

    if not isinstance(template, dict):
        return [ValidationIssue("invalid_template", display_path)]

    if not isinstance(data, dict):
        return [ValidationIssue("bad_type", display_path, dict, type(data))]

    # JSON objects cannot contain cycles, but ordinary Python dicts can.
    if id(data) in data_ancestors:
        return [ValidationIssue("cycle", display_path, detail="data")]
    if id(template) in template_ancestors:
        return [ValidationIssue("cycle", display_path, detail="template")]

    next_data_ancestors = set(data_ancestors)
    next_template_ancestors = set(template_ancestors)
    next_data_ancestors.add(id(data))
    next_template_ancestors.add(id(template))

    issues = []

    # Report every missing required key in template order.
    for key in template:
        if key not in data:
            issues.append(ValidationIssue("missing_key", _path(path, key)))

    # Report every forbidden extra key in data order.
    for key in data:
        if key not in template:
            issues.append(ValidationIssue("extra_key", _path(path, key)))

    # Continue validating only keys that exist in both structures.
    for key in template:
        if key not in data:
            continue

        expected = template[key]
        value = data[key]
        current_path = _path(path, key)

        if isinstance(expected, dict):
            issues.extend(
                _collect_issues(
                    value,
                    expected,
                    current_path,
                    next_data_ancestors,
                    next_template_ancestors,
                )
            )
        elif isinstance(expected, type):
            if type(value) is not expected:
                issues.append(
                    ValidationIssue(
                        "bad_type",
                        current_path,
                        expected=expected,
                        actual=type(value),
                    )
                )
        else:
            issues.append(ValidationIssue("invalid_template", current_path))

    return issues


def validate_all(data, template):
    """Return a list of all discoverable validation issues."""
    return _collect_issues(data, template)


def is_valid(data, template):
    """Convenience predicate for code that only needs a boolean."""
    return not validate_all(data, template)

# %% [markdown]
# ### Example: multiple failures in one payload
#
# This deliberately malformed object contains several independent problems. `validate_all` reports them together, which is useful when returning a `400 Bad Request` response from an API.

# %%
from copy import deepcopy

broken = deepcopy(john)
broken["user_id"] = "100"                      # wrong type
broken["name"].pop("last")                    # missing key
broken["bio"]["dob"]["month"] = "November"  # wrong type
broken["bio"]["birthplace"]["planet"] = "Earth"  # extra key

issues = validate_all(broken, template)

for issue in issues:
    print(issue.as_dict())

assert [issue.message for issue in issues] == [
    "bad type: user_id",
    "mismatched keys: name.last",
    "bad type: bio.dob.month",
    "mismatched keys: bio.birthplace.planet",
]
# Out:
# {'kind': 'bad_type', 'path': 'user_id', 'message': 'bad type: user_id', 'expected': 'int', 'actual': 'str', 'detail': None}
# {'kind': 'missing_key', 'path': 'name.last', 'message': 'mismatched keys: name.last', 'expected': None, 'actual': None, 'detail': None}
# {'kind': 'bad_type', 'path': 'bio.dob.month', 'message': 'bad type: bio.dob.month', 'expected': 'int', 'actual': 'str', 'detail': None}
# {'kind': 'extra_key', 'path': 'bio.birthplace.planet', 'message': 'mismatched keys: bio.birthplace.planet', 'expected': None, 'actual': None, 'detail': None}

# %% [markdown]
# ## Batch validation helper
#
# A common real-world use case is validating many records before importing them. The helper below returns only invalid records, keyed by their input index.

# %%
def validate_many(records, template):
    """Validate an iterable of records and return diagnostics for invalid rows."""
    failures = {}
    for index, record in enumerate(records):
        issues = validate_all(record, template)
        if issues:
            failures[index] = [issue.as_dict() for issue in issues]
    return failures


batch_failures = validate_many([john, eric, michael], template)

assert 0 not in batch_failures
assert batch_failures[1][0]["message"] == "mismatched keys: bio.birthplace.city"
assert batch_failures[2][0]["message"] == "bad type: bio.dob.month"

batch_failures
# Out:
# {1: [{'kind': 'missing_key',
#    'path': 'bio.birthplace.city',
#    'message': 'mismatched keys: bio.birthplace.city',
#    'expected': None,
#    'actual': None,
#    'detail': None}],
#  2: [{'kind': 'bad_type',
#    'path': 'bio.dob.month',
#    'message': 'bad type: bio.dob.month',
#    'expected': 'int',
#    'actual': 'str',
#    'detail': None}]}

# %% [markdown]
# ## Defensive test: cyclic Python dictionaries
#
# This is not possible in valid JSON, but it is possible in Python. Cycle detection prevents infinite recursion if the validator is reused outside a strict JSON boundary.

# %%
cyclic_template = {"node": {}}
cyclic_template["node"]["again"] = cyclic_template["node"]

cyclic_data = {"node": {}}
cyclic_data["node"]["again"] = cyclic_data["node"]

cycle_issues = validate_all(cyclic_data, cyclic_template)

assert len(cycle_issues) == 1
assert cycle_issues[0].message == "cyclic reference: node.again"
cycle_issues[0].as_dict()
# Out:
# {'kind': 'cycle',
#  'path': 'node.again',
#  'message': 'cyclic reference: node.again',
#  'expected': None,
#  'actual': None,
#  'detail': 'data'}

# %% [markdown]
# ## Choosing the API
#
# | Need | Recommended call |
# | --- | --- |
# | Match the original assignment exactly | `validate(data, template)` |
# | Fail immediately and handle exceptions | `validate_or_raise(data, template)` |
# | Only need a boolean | `is_valid(data, template)` |
# | Show a client every problem at once | `validate_all(data, template)` |
# | Validate an import/batch | `validate_many(records, template)` |
#
# This keeps the assignment solution small and correct while exposing patterns that scale naturally to API and data-ingestion code.
